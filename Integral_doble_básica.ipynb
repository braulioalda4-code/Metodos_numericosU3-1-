# %% [markdown]
# <a href="https://colab.research.google.com/github/braulioalda4-code/Metodos_numericosU3-1-/blob/main/Integral_doble_b%C3%A1sica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 1 - Integral doble básica

# %%
import numpy as np # Importa la bibioteca NumPy para cálculos numéricos

def f(x,y): # Define la función de dos variables
    return x + y # Retorna la suma de la variables

a, b = 0, 1 # Define los límites en el eje x
c, d = 0, 1 # Define los límites en el eje y

n = 50 # Número de divisiones en x
m = 50 # Número de divisiones en y

dx = (b-a)/n # Calcula el tamaño del paso en x
dy = (d-c)/m # Calcula el tamaño del paso en y

integral = 0 # Inicializa el acumulador de la integral

for i in range(n): # Itera sobre las particiones en x
    for j in range(m): # Itera sobre las particiones en y
        x = a + i*dx # Calcula la coordenada x en la malla
        y = c + j*dy # Calcula la coordenada y en la malla

        integral += f(x,y)*dx*dy # Suma el área elemental

print("Integral doble aproximada:", integral) # Muestra el resultado
