# %% [markdown]
# <a href="https://colab.research.google.com/github/braulioalda4-code/Metodos_numericosU3-1-/blob/main/Resoluci%C3%B3n_SciPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 2-Resolución con SciPy

# %%
import numpy as np # Biblioteca para cálculos númericos
from scipy.optimize import fsolve # Importa el método fsolve para resolver sistemas no lineales

def sistema(vars): # Define la función que representa el sistema de ecuaciones
    x, y = vars # Separa la variables del vector de entrada
    f1 = x**2 + y**2 - 4 # Primera ecuación del sistema
    f2 = x - y - 1 # Segunda ecuación del sistema
    return [f1, f2] # Devuelve el sistema evaluado

sol = fsolve(sistema, [1,1]) #Busca la solución usando como aproximación inicial (1,1)

print("Solución aproximada:", sol) # Imprime la solución encontrada
# Out:
# Solución aproximada: [1.82287566 0.82287566]
